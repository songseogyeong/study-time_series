# %% [markdown]
# ### 자기회귀(AR, Autoregressice Model)
# - 현 시점의 자료가 p시점 전의 유한개의 과거 자료로 설명될 수 잇따.
# - 과거의 데이터가 미래 데이터에 영향을 준다고 가정하는 모델이다.
# - 현 시점의 시계열 자료에서 몇 번째 전 자료까지 영향을 주는 가를 파악한은 데에 사용한다.
# - 현재 시점의 데이터가 직전 시점의 데이터에만 영향을 받는 모델을 1차 자기 회귀 모형이라고 하고, AR(1)로 표기한다.
# - 이를 알아내기 위해서는 데이터의 패턴을 분석하고, 이 때 ACF, PACF를 사용한다.
# - 표준정규분포 영역 내에 들어가는 첫 번째 지점을 절단점이라고 하며, 절단점에서 1을 빼준 값이 AR 모델의 차수이다.
#
# > 1. ACF
# > 만약 자기회귀 모델이라면,
# > 현재 데이터와 멀리 떨어진 과거 데이터의 영향력은 점점 줄어들기 때문에 시간이 지남에 따라 상관관계가 줄어든다.
#
# > 2. PACF
# > 만약 자기회귀 모델이라면,
# > 특정 시점 이후에 급격히 감소하는 모양이 나타난다.
#
# - 즉, 자기회귀 모델이라면, ACF는 시차가 증가함에 따라 점차 감소하고 PACF는 특정 시점 이후 급격히 감소하여 절단된 형태를 보인다.
# - 자기회귀 모델을 식별함으로써 데이터의 기본 패턴과 구조를 이해할 수 있고,
#   이를 통해 데이터가 어떻게 변동하는지, 과거 데이터가 미래에 어떤 영향을 미치는지에 대한 통찰력을 제공한다.
#
# ---
# 선형결합
# 현재 자료가 과거 자료로써 설명될 수 있다
# 과거가 이래서 이렇게 될 수 있는거야 = 자기 회귀
# 과거께 현재 현재께 미래
# 전시점 + 현시점 + 미래 >  선형결합해서 회귀
# 그래서 몇번째까지 영향이 있는가? 라그를 몇번째까지
# 1.96 범위 사이에 들어가는 점을 절단점이라고 함
# 영역으로 들어감 절단점...
# 라그 2라고 했을 때 라그 2에 -1하면 1을 AR모델에 넣기
# 차분까지 해주는 아리마가 있고...
#
# AR에 전달해야 하는 라그 값은
# ACF, PACF로 찾아내기 절단점
#
# AR(1)이면 어제꺼랑만 영향을 주고 받음
# 직전껄로만 하기
#
# 차분하면 맨 첫번쨰가 NAN값이 되고..
# 그러다보면 1을 빼줘야한다?
#
# 자기 회귀 모델인지 판단은 어케해?
# ACF, PACF 시각화했을 때 모양이 어떻게 나오는지 보고 결정
#
#
# acf 누적
# 백년전 어제중 어제가 더 영향력을 끼침
# 점점 감소하는 추세가 나와야 한다

# %%
import yfinance as yf

google_stock_df = yf.download('GOOG', start='2014-05-01')
google_stock_df = google_stock_df['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, ax = plt.subplots(3, 2, figsize=(12, 20))

# 정상성이 없는 데이터를 acf와 pacf로 가져오기ㅠ
plot_acf(google_stock_df, lags=20, ax=ax[0][0])
plot_pacf(google_stock_df, lags=20, ax=ax[0][1])

# 차분
plot_acf(google_stock_df.diff().dropna(), lags=20, ax=ax[1][0])
plot_pacf(google_stock_df.diff().dropna(), lags=20, ax=ax[1][1])

# 정확한것, acf로 보고 pacf하기
plot_acf(google_stock_df, lags=20, ax=ax[2][0])
plot_pacf(google_stock_df.diff().dropna(), lags=20, ax=ax[2][1])


plt.show()

# 왼쪽 점점 감소함
# 오른쪽 절단점이 나오고 라그가 2가 들어가는 것을 보임 즉, AR(1)이 됨
# 절단점 -1 = 라그 -1 = 2 -1 = AR(1)
# ---
# 왼쪽 ACF, PACF 의 값이 거의 같다(다르긴함)

# %%
# 원본에서 차분 횟수를 알아낼 수 있음!
# 0으로부터 멀어질수록 상관관계가 낮음, pacf는 0에 가까워야 상관관계가 높음
# 0에 수렴한 다음에 가장 많이 떨어진 절단점을 찾아야함 

처음으로 0으로 수렴했을 때 이후의 시점을 보면 됨
그로부터 가장 떨어져있는 걸 확인 그러면 아리마 모델에 맞춰서 쓰면됨...

# %% [markdown]
# ### 이동 평균 (MA, Moving Avearage)
# - 일정 기간 동안의 데이터를 평균하여 시계열 데이터의 부드러운 패턴을 확인할 수 있게 해준다.
# - 특정 기간 동안의 데이터를 평균한 값으로, 시계열 데이터의 일정 기간 동안의 평균을 보여준다.
# - 데이터의 변동을 부드럽게 만들어서 패턴을 파악하는 데 도움이 되며, 시계열 데이터의 추세를 이해하고 예측하는 데에 유용한 도구이다.
#
# <img src='./images/ma.jpg'>
#
# ---
# 윈도우 슬라이딩 알고리즘(stride) 하면 2칸 이동하고 한 거랑 똑같음
# 10개 단위를 평균내기
# 스무딩이 됨 =플랫해짐
#
# 주식 그래프가 뾰족한 걸
# MA하면 곡선 형태로 평균내서 고쳐줌
# 라그만큼 이동하면서 바꿈... 그래서 이동 평균!!
#
# 이동 평균 쓰면 바이어스에 민감하지 않음
# 그래서 쇼크에 대비할 수 있는게 이동평균
#
# 이동평균을 어떻게 주냐에 따라 성능이 달라짐!
#
# 이미지 MA3 = 3개의 라그
#
# 바이어스가 있는 걸 잡아줌
# 추세가 있다 =트렌디 하는 걸 알 수 이ㅣㅆ음
# 계쩔이 있다 시즈널이 있따 는 것을 알 수 있음
#
# 실무에 적용하면 ?
# 아이스크림 가게
# 아이스크림 팔기
# 이제 여름이 됨
# 아이스크림 여름에는 상승한다고 가정
# 얼만큼 아이스크림을 미리 준비해야하는가? > 아이스크림 사장님 고충
# 일주일 전이 7일 전만 보고 는 힘들어
# 값을 1개만 가지고는 힘들어!
# 그러면 7일 이동 평균을 구하면 됨!
# 일주일 일주일 일주일 평균평균평균을 구하는 거임
# 그러면 이번에는 몇개를 준비해야겠구나를 평균값으로 나옴
# 이럴때 이동평균을 사용
# 하나만 보고 367개를 준비하느니 그 주의 평균이 350인걸 보는게 좋음
# 하나만 보면 그날 쇼크가 있던 날일 수도 있음

# %%
import yfinance as yf

google_stock_df = yf.download('GOOG', start='2014-05-01')
google_stock_df = google_stock_df['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
google_stock_diff_df = google_stock_df.diff()
google_stock_diff_df.dropna(inplace=True)
google_stock_diff_df
# Out:
# Date
# 2014-05-02   -0.170532
# 2014-05-05   -0.005983
# 2014-05-06   -0.631765
# 2014-05-07   -0.258291
# 2014-05-08    0.051859
#                 ...
# 2024-06-04    0.710007
# 2024-06-05    1.940002
# 2024-06-06    1.279999
# 2024-06-07   -2.400009
# 2024-06-10    0.680008
# Name: Adj Close, Length: 2544, dtype: float64

# %%
# 롤링 = 플랫하게 만들어줌
# 윈도우의 크기 = 라그수를 전달해야함
window_size = 20

# 이동평균..
moving_avg = google_stock_diff_df.rolling(window_size).mean()
moving_avg

window_size = 20

moving_avg = google_stock_df.rolling(window_size).mean()
print(moving_avg)

moving_avg_diff = google_stock_diff_df.rolling(window_size).mean()
print(moving_avg_diff)

# 아래 있는게 더 일정하다.... 차분을 했으니까!
# Out:
# Date
# 2014-05-02         NaN
# 2014-05-05         NaN
# 2014-05-06         NaN
# 2014-05-07         NaN
# 2014-05-08         NaN
#                 ...
# 2024-06-04    0.265000
# 2024-06-05    0.204501
# 2024-06-06    0.359500
# 2024-06-07    0.218500
# 2024-06-10    0.317001
# Name: Adj Close, Length: 2544, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 20))

plt.subplot(2, 1, 1)
plt.plot(google_stock_df, c='orange')

plt.subplot(2, 1, 1)
plt.plot(moving_avg)

plt.title('Google stock MR (2014~2024)')

plt.subplot(2, 1, 2)
plt.plot(google_stock_diff_df, c='orange')

plt.subplot(2, 1, 2)
plt.plot(moving_avg_diff)

plt.title('Google stock differencing MR (2014~2024)')

plt.show()

# 분포가 컸던 부분이 스무딩이 됨 예측을 더 잘 할 수 있을 것

# %%
AR에 들어가는 차수는 acf랑 pacf를 보고 결정해서 넣으면 됨
ar은 어떤 시점과 어떤 시점으로 부터 떨어진 점이 몇 라그까지 관련이 있는지를 넣고

MA는 안에 20넣으면 20일 평균으로 이동됨!

# %% [markdown]
# ### 안정 시계열 (ARMA)
# - 과거의 데이터와 최근의 평균을 사용하여 시계열 데이터의 패턴을 파악하고 예측하는 데에 사용한다.
# - 2022년 3월 기준으로 ARMA가 중단되고 ARIMA로 대체되었다.
# - ARMA 모델은 시계열 데이터의 과거 값을 기반으로 한 선형 예측 모델이기 때문에 시계열 데이터가 정상성을 보이고,
#   예측에 영향을 주는 외부 요인이 없는 등의 가정을 만족해야 한다.
#   =차분을 하고 나서 알마를 서야함..
# - 비정상성 데이터나 비선형적인 패턴을 갖는 데이터의 경우 패턴 파악 및 예측이 어렵다.
# - ARMA(1, 0) = AR(1)
# - ARMA(0, 1) = MA(1)
# - MARMA(1, 1) = AR(1), MA(1)
#
# ---
# 그냐 ㅇ알마 모델임!
# 프리딕트 가능!
#
# 알마랑 아리마 둘다 있었는데
# 안정 시계열 =정상 시계열..
# 세상에 정상성을 띈 시계열이 얼마나 되냐!
# 보니까 알마 사용율이 떨어짐
# 그래서 불안정이든 안정이든 아리마로 쓰자!
# 아리마에 0을쓰면 차분을 안한다는 뜻
# 그래서 불안정 시계열을 쓸 수 있는 아리마로 쓰자!
#
# ---
#
# ### 불안정 시계열 (ARIMA)
# - ARIMA(p, d, q): d차로 차분한 데이터에 AR(p)모형과 MA(q)모형을 합친 모델이다.
# - Autoregressice, Integrated(누적 차분), Moving Average의 세 가지 요소로 구성되어 있다.
# - I는 비정상 시계열을 정상 시계열로 만들기 위해서 필요한 차분 횟수를 의미한다.
#
#
# ---
# 전체 데이터 all에서 트레인 테스트로 나누고
# 트레인을 가지고 테스트로 예측하기
# 그래서 프리딕트한 선이 맞는지 예측함...!
#
#
# 정리
# 정상성을 띄어야 함
# 정상성인지 비정상인지 구분acf사용!
# 정상성을 띄려면 차분
# 그리거 pacf를 보고 독립적인 상관관계를 확인
#
# 그걸 보고ar에 어떤 차수 넣을지 결정
# 근데 바이어스를 부드럽게 만들기 위해 ma를 같이 씀
#
# 여기서 성능을 더 좋게 하기 위한 알마를 사용
# 알마는 정상만 쓸 수있음 안정 시계열
#
# 그래서 차분까지 해주는
# 아리마까지 나옴
# 아리마가 의미하는 i는 차분 횟수!

# %% [markdown]
# #### ARIMA

# %%
google_stock_df.info()

# DatetimeIndex 이어야만 아리마에서 문제가 없음!
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 2545 entries, 2014-05-01 to 2024-06-10
# Series name: Adj Close
# Non-Null Count  Dtype
# --------------  -----
# 2545 non-null   float64
# dtypes: float64(1)
# memory usage: 39.8 KB

# %%
# import pandas as pd

# # 인덱스 타입 변경 (그냥 index라면)
# google_stock_df = google_stock_df.reindex(pd.date_range(google_stock_df.index[0], google_stock_df.index[-1])

# %%
# nall 값 확인
google_stock_df.isna().any()
# Out:
# False

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# model = ARIMA(데이터, order=(p, d, q))

model = ARIMA(google_stock_df, order=(1, 1, 1))
# 아리마는 fit을 저장해야함, cnn history 객체랑 유사..
model_fit = model.fit()

# train 차분함 누적차분함.. 누적을 할 때 마지막 데이터를 통해서 바로 다음 라그는 예측이 가능하지만 그 다음거는 예측할 수 없음
# fit에서 업데이트를 한 적이 없으니까 
# 트레인에서 테스트 예측이 불가함(시계열에서)
# 시계열 데이터 모델이 예측을 하는 알고리즘 자체가 전에에 차분에 대한 다음을 예측함, 직전꺼가 필요함 다음꺼를 예측하려면 이전시점에 대한 연산 값이 필요함
# 그래서 n하고 n+1 결과를 또 핏함 그럼 그 결과로 또 구함 ... 즉 업데이트함, 업데이트를 토 ㅇ해 예측함

# 핏을 했을 때 포함되는 기간 내로 해야함
start_index = pd.to_datetime('2022-02-01')
end_index = pd.to_datetime('2024-04-17')
# predict = forcast
forcast = model_fit.predict(start=start_index, end=end_index)

# 전체 훈련시키고> 훈련시키는 거 중에 맞추는건 훈련한걸로 훈련하고 예측한거임 (테스트 없음)

plt.figure(figsize=(15, 8))
plt.plot(google_stock_df, label='original')
plt.plot(forcast, label='predicted', c='orange')
plt.title("Time Series Forecast")
plt.legend()
plt.show()

# 모델평가임!
# 예측 값이 실제 값을 잘 따라가는지 보며 모델 평가함.
# Out:
# C:\Users\LEGION\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\LEGION\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\LEGION\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error

# 실제 데이터, 예측
mse = mean_squared_error(google_stock_df['2022-02-01': '2024-04-17'], forcast)
print("Mean Squared Error", mse)

# 로그 씌어서 비중이됨(퍼센트)
msle = mean_squared_log_error(google_stock_df['2022-02-01': '2024-04-17'], forcast)
print("Mean Squared Error", msle)
# Out:
# Mean Squared Error 6.38921898108315
# Mean Squared Error 0.00045602247138405407

# %%
ma 값은 임의로 넣기... 스무딩 되게끔!
